# %% [markdown]
# # Analysis of Chicago Crime
#
# ## Introduction
# Crime in Chicago has been making headlines lately.

# %%
# libraries we will need
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ID
# Case Number
# Date
# Block
# IUCR
# Primary Type
# Description
# Location Description
# Arrest
# Domestic
# Beat
# District
# Ward
# Community Area
# FBI Code
# X Coordinate
# Y Coordinate
# Year
# Updated On
# Latitude
# Longitude
# Location

# %%
# We will be using data from https://www.kaggle.com/currie32/crimes-in-chicago

df = pd.read_csv("Chicago_Crimes_2012_to_2017.csv")

# %%
df.info()
print(df.head(10))
df.shape

# as seen the data contains 1.456.714 entries
# some have non-null objects
#case number with 1
#Location Description with 1658
# District with 1
# Ward with 14
# Community area with 40
# X Coordinate with 37.083
# Y Coordinate with 37.083
# Latitude: 37.083
# Longitude: 37.083
# Location: 37.083
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456714 entries, 0 to 1456713
# Data columns (total 23 columns):
# Unnamed: 0              1456714 non-null int64
# ID                      1456714 non-null int64
# Case Number             1456713 non-null object
# Date                    1456714 non-null object
# Block                   1456714 non-null object
# IUCR                    1456714 non-null object
# Primary Type            1456714 non-null object
# Description             1456714 non-null object
# Location Description    1455056 non-null object
# Arrest                  1456714 non-null bool
# Domestic                1456714 non-null bool
# Beat                    1456714 non-null int64
# District                1456713 non-null float64
# Ward                    1456700 non-null float64
# Community Area          1456674 non-null float64
# FBI Code                1456714 non-null object
# X Coordinate            1419631 non-null float64
# ...

# %%
df[df["Location Description"].isnull()]
#1658 records that have Location Description as NaN
#we see that most have Financial identity Theft
#let's create another location to location description for these kind of crimes
# Out:
#          Unnamed: 0        ID Case Number                    Date  \
# 98            21406  10509988    HZ250746  05/03/2016 04:35:00 PM
# 133           30452  10511522    HZ251882  05/03/2016 08:00:00 AM
# 171           41198  10515761    HZ257158  03/09/2016 10:45:00 AM
# 471          129890  10509989    HZ251113  05/04/2016 12:00:00 PM
# 690          190151  10511523    HZ252317  05/04/2016 10:00:00 AM
# 708          195956  10512795    HZ253514  05/04/2016 11:30:00 AM
# 909          242116  10509982    HZ251129  04/29/2015 01:20:00 PM
# 1020         269328  10518590    HZ259878  02/26/2014 10:15:00 PM
# 1021         269437  10518604    HZ260048  04/14/2016 09:00:00 AM
# 1023         269679  10518612    HZ260047  04/03/2016 02:00:00 PM
# 1027         270094  10518625    HZ259943  03/18/2013 10:25:00 AM
# 1930         440465  10512796    HZ253518  05/06/2016 09:45:00 AM
# 1997         450939  10520068    HZ261435  10/01/2014 03:35:00 PM
# ...

# %%
df.loc[(df['ID'] == 10509988) & (df['IUCR'] != 1154)]
# Out:
#     Unnamed: 0        ID Case Number                    Date  \
# 98       21406  10509988    HZ250746  05/03/2016 04:35:00 PM
#
#                     Block  IUCR        Primary Type  \
# 98  029XX N SHEFFIELD AVE  1154  DECEPTIVE PRACTICE
#
#                                 Description Location Description  Arrest  \
# 98  FINANCIAL IDENTITY THEFT $300 AND UNDER                  NaN    True
#
#                 ...                Ward  Community Area  FBI Code  \
# 98              ...                44.0             6.0        11
#
#     X Coordinate  Y Coordinate  Year              Updated On   Latitude  \
# 98     1169107.0     1919625.0  2016  05/10/2016 03:56:50 PM  41.934969
#
#     Longitude                       Location
# 98 -87.653937  (41.934968944, -87.653936849)
#
# [1 rows x 23 columns]
